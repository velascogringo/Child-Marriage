# %% [markdown]
# <a href="https://colab.research.google.com/github/velascogringo/Child-Marriage/blob/main/Child_Marriage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
#mount drive
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import libraries

# %%
file = '/content/drive/MyDrive/Colab Notebooks/viz5_child_marriage.csv'
df = pd.read_csv(file)
df.head() #show 1st five
# Out:
#        country  females_married_by_15  females_married_by_18  \
# 0  Afghanistan                  0.042                  0.283
# 1      Albania                  0.014                  0.118
# 2      Algeria                  0.004                  0.025
# 3       Angola                  0.079                  0.303
# 4      Armenia                  0.000                  0.053
#
#    males_married_by_18
# 0                0.073
# 1                0.012
# 2                  NaN
# 3                0.060
# 4                0.004

# %%
df.shape #128 rows, 4 columns
# Out:
# (128, 4)

# %%
top10fem15 = df.sort_values(['females_married_by_15'], ascending= False).head(10)
top10fem15[['country','females_married_by_15']]
#look for top 10 countries where females are getting married by age of 15
# Out:
#                      country  females_married_by_15
# 21                      Chad                  0.297
# 20  Central African Republic                  0.291
# 79                     Niger                  0.280
# 6                 Bangladesh                  0.224
# 68                Mauritania                  0.178
# 44                    Guinea                  0.170
# 73                Mozambique                  0.168
# 66                      Mali                  0.159
# 80                   Nigeria                  0.157
# 38                  Ethiopia                  0.141

# %%
fig, ax = plt.subplots(figsize = (15,7))
sns.barplot(data=top10fem15, x='country', y='females_married_by_15')
ax.set_xlabel('Country')
ax.set_ylabel('Percentage')
ax.set_title('Top 10 Countries with Females Getting Married by Age of 15')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
plt.legend();
plt.show();

#create bar chart of top 10 fem getting married by 15
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
top10fem18 = df.sort_values(['females_married_by_18'], ascending= False).head(10)
top10fem18[['country','females_married_by_18']]
#look for top 10 countries where females are getting married by age of 18
# Out:
#                       country  females_married_by_18
# 79                      Niger                  0.763
# 20   Central African Republic                  0.679
# 21                       Chad                  0.669
# 6                  Bangladesh                  0.586
# 66                       Mali                  0.537
# 73                 Mozambique                  0.529
# 15               Burkina Faso                  0.516
# 102               South Sudan                  0.515
# 44                     Guinea                  0.465
# 100                   Somalia                  0.453

# %%
fig, ax = plt.subplots(figsize = (15,7))
sns.barplot(data=top10fem18, x='country', y='females_married_by_18')
ax.set_xlabel('Country')
ax.set_ylabel('Percentage')
ax.set_title('Top 10 Countries with Females Getting Married by Age of 18')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
plt.legend();
plt.show();

#create bar chart of top 10 fem getting married by 18
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
top10male18 = df.sort_values(['males_married_by_18'], ascending= False).head(10)
top10male18[['country','males_married_by_18']]
#look for top 10 countries where males are getting married by age of 18
# Out:
#                               country  males_married_by_18
# 20           Central African Republic                0.279
# 9                              Belize                0.222
# 106                          Suriname                0.196
# 78                          Nicaragua                0.194
# 63                         Madagascar                0.129
# 76                              Nauru                0.123
# 48                           Honduras                0.122
# 23                            Comoros                0.119
# 67                   Marshall Islands                0.118
# 59   Lao People's Democratic Republic                0.108

# %%
fig, ax = plt.subplots(figsize = (15,7))
sns.barplot(data=top10male18, x='country', y='males_married_by_18')
ax.set_xlabel('Country')
ax.set_ylabel('Percentage')
ax.set_title('Top 10 Countries with Males Getting Married by Age of 18')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
plt.legend();
plt.show();

#create bar chart of top 10 fem getting married by 18
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
